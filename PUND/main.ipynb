# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import json
from matplotlib import colormaps
import re
import io
from datetime import datetime

from src.metadata_utils import Extract_data_and_metadata
from src.Plot import PUND_collumn_splitter, Plot_multi_PUND
from src.export import export_csv
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# This code is used to plot the data from the FE tester for the CV
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %config InlineBackend.figure_format = 'retina' # For high resolution figures in Jupyter Notebook
#%matplotlib widget

# %% [markdown]
# ## Operator window

# %% [markdown]
# #### Parameters to Specify ####
#  - **Input file path**
#  - **Output file path**
#  - **File name**
#  - **Number of points to remove** (in case of breakdown)

# %%
# Set the path to the data file
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

file_path = r'/home/nathan-savoia/Documents/PhD/Nextcloud/06 - FeCAP-FTJ/02 - Data/02 - FE tester/NASA-007-02/PUND'
output_path = r'/home/nathan-savoia/Documents/PhD/Nextcloud/06 - FeCAP-FTJ/01 - Results/02 - FE tester/NASA-007-02/PUND'
file_name = 'NASA-007-02_ID06-01_PUND.dat'
full_path = os.path.join(file_path, file_name)

# Extract the last folder name from the file path
last_folder = os.path.basename(os.path.dirname(file_path))
print(last_folder)

# Séparer nom et extension
base_name = os.path.splitext(file_name)[0]
print(f"Name of the device: {base_name}")  # ➜ NASA_SL_ALE_10_ID_095
output_path = os.path.join(output_path, base_name)
os.makedirs(output_path, exist_ok=True)
# Out:
# NASA-007-02
# Name of the device: NASA-007-02_ID06-01_PUND

# %% [markdown]
# ## PUND analysis ##

# %%
# Extract data and metadata
PUND_dataframe, metadata_dict_PUND = Extract_data_and_metadata(full_path)
# Out:
# 8 P-V loops loaded.

# %% [markdown]
# ## Plots ##

# %%
# Plot the results

label_size = 15
Plot_multi_PUND(PUND_dataframe, output_path, label_size, base_name, metadata_dict_PUND)
export_csv(PUND_dataframe, metadata_dict_PUND, output_path, base_name)
