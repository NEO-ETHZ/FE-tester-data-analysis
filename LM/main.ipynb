# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import json
from matplotlib import colormaps
import re
import io
from datetime import datetime

from src.utils import Extract_data_and_metadata
from src.plot import LM_dashboard, LM_plot_linear, LM_plot_log
#from src.export import export_csv
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# This code is used to plot the data from the FE tester for the CV
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %config InlineBackend.figure_format = 'retina' # For high resolution figures in Jupyter Notebook
#%matplotlib widget

# %%
# Set the path to the data file
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

file_path = r'E:\Polybox\06 - FeCAP-FTJ\02 - Data\02 - FE tester\NASA_FeCAP_03\Leakage measurement'
output_path = r'E:\Polybox\06 - FeCAP-FTJ\01 - Results\02 - FE tester\NASA_FeCAP_03\Leakage measurement'
file_name = '2026-02-02_NASA-FeCAP-03_ID02-03.dat'
full_path = os.path.join(file_path, file_name)

# Extract the last folder name from the file path
last_folder = os.path.basename(os.path.dirname(file_path))
print(last_folder)

# Séparer nom et extension
base_name = os.path.splitext(file_name)[0]
print(f"Name of the device: {base_name}")
output_path = os.path.join(output_path, base_name)
os.makedirs(output_path, exist_ok=True)
# Out:
# NASA_FeCAP_03
# Name of the device: 2026-02-02_NASA-FeCAP-03_ID02-03

# %%
LM_dataframe, metadata_df = Extract_data_and_metadata(full_path)
LM_dashboard(LM_dataframe, metadata_df, output_path=output_path, base_name=base_name)
# Out:
# 1 LM loaded.

# %%
LM_plot_linear(LM_dataframe=LM_dataframe, metadata_df=metadata_df, output_path=output_path, base_name=base_name)
LM_plot_log(LM_dataframe=LM_dataframe, metadata_df=metadata_df, output_path=output_path, base_name=base_name)
