# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import json
from matplotlib import colormaps
import re
import io
from datetime import datetime

from src.metadata_utils import Extract_data_and_metadata
from src.Plot import DHM_plot
from src.export import export_csv
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# This code is used to plot the data from the FE tester for the CV
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %config InlineBackend.figure_format = 'retina' # For high resolution figures in Jupyter Notebook
#%matplotlib widget

# %% [markdown]
# ## Operator window

# %% [markdown]
# #### Parameters to Specify
#
# - **Input file path**
# - **File name**

# %%
# Set the path to the data file
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

file_path = r'/home/nathan-savoia/Documents/PhD/Nextcloud/00 - ViFOX/02 - Data/02 - FE tester/NASA_SL_ALE_10/DHM'
output_path = r'/home/nathan-savoia/Documents/PhD/Nextcloud/00 - ViFOX/01 - Results/02 - FE tester/NASA_SL_ALE_10/DHM'
file_name = 'NASA_SL_ALE_10_ID_60.dat'
full_path = os.path.join(file_path, file_name)

# Extract the last folder name from the file path
last_folder = os.path.basename(os.path.dirname(file_path))
print(last_folder)

# Séparer nom et extension
base_name = os.path.splitext(file_name)[0]
print(f"Name of the device: {base_name}")
output_path = os.path.join(output_path, base_name)
os.makedirs(output_path, exist_ok=True)
# Out:
# NASA_SL_ALE_10
# Name of the device: NASA_SL_ALE_10_ID_60

# %% [markdown]
# ## DHM analysis

# %% [markdown]
# Data analysis

# %%
# Extract data and metadata
DHM_dataframe, metadata_df = Extract_data_and_metadata(full_path)
export_csv(DHM_dataframe, metadata_df, output_path, base_name)
# Out:
# 6 P-V loops loaded.

# %% [markdown]
# Plot

# %%
# Création du colormap (dégradé de bleu clair à bleu foncé)

color_PV = (0.15, 0.65, 0.35)
color_IV = (0.25, 0.45, 0.65)
label_size = 15

DHM_plot(DHM_dataframe, metadata_df, label_size, color_PV, color_IV, output_path, base_name)
